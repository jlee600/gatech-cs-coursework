# %% [markdown]
# # Spring 2026 CS4641/CS7641 Homework 1 - Programming Section

# %% [markdown]
# ## Instructors: Dr. Max Mahdi Roozbahani, Dr. Nimisha Roy

# %% [markdown]
# ### Important Directives
#
# <!-- No changes needed on the below section -->
# * No unapproved extension of the deadline is allowed. For late submissions, please refer to the course website.
#
# * This notebook is not graded, but will act as a useful guide to the content of the homework, which is autograded. You may use it however you wish. Note that the notebook sometimes contains scripts which generate checkpoint files or other artifacts that are sometimes required for submission. You can theoretically generate all homework deliverables without the notebook, but directions and often automated scripting cells are contained in the notebook to make your HW experience easier.
#
# * Discussion is encouraged! You are welcome to discuss at a whiteboard level with peers, but each student must write their own code. <font color='darkred'>Plagiarism is a **serious offense**.</font> You are not allowed to copy and paste or submit materials created or published by others, as if you created the materials. A good heuristic for cooperation is to discuss the questions together without discussing specifics, then write up your code separately. If a conversation with a peer was meaningfully useful, you should cite them in-place with a comment.
#
# * <font color='darkred'>Working with a generative-AI platform **may constitute plagiarism**.</font> In line with the Joyner Heuristic being used by many classes at GT, you should treat collaboration with generative-AI as collaboration with a knowledgeable peer. It would be appropriate to ask about topics, syntax, or package functions, but inappropriate to share the question and ask them to solve it. **Sharing the question or your work verbatim with an AI agent so as to generate an answer to the question is considered academic dishonesty and will be treated the same as any other incident of academic dishonesty.** If you're stuck, make a post on Ed, or visit office hours!
#
# * <font color='darkred'>All incidents of suspected dishonesty, plagiarism, or violations of the Georgia Tech Honor Code will be subject to the institute's Academic Integrity procedures. If we observe any (even small) issues detected by Gradescope or our TAs, **WE WILL DIRECTLY REPORT ALL CASES TO OSI**, which may, unfortunately, lead to a very harsh outcome, for example, academic probation or dismissal, a 0 grade for assignments concerned, and prohibition from withdrawing from the class.</font>

# %% [markdown]
# ## Instructions for the assignment

# %% [markdown]
# - This assignment consists of both programming and theory questions.
#
# - Theory questions are contained in the separate non-programming folder.
#
# - **Graduate Students**: You are required to complete any sections marked as Bonus for Undergrads.
#
# - Homework 1's programming section consists of some quick warm-up programming questions designed to get you familiar with our programming homework structure.

# %% [markdown]
# ### Using the autograder
#
# - Grads will typically find three assignments on Gradescope and Undergrads will typically find four assignments:
#     - "Assignment X Non-programming": Where you will submit the written portion of the assignment.
#     - "Assignment X Programming": Where you will submit any .py files and any program outputs as required by the base questions.
#     - "Assignment X Programming - Bonus for All": Where you will submit any .py files and any program outputs as required for Bonus for All.
#     - "Assignment X Programming - Bonus for Undergrad": Where you will submit any .py files and any program outputs as required for Bonus for Undergrand. (Undergrad Only)
#     - Testcases that would be Bonus for Undergrad will be contained in the base "Assignment X Programming" for grads.
#     - On HW1 specifically, there are no programming bonus questions, so you will only find the base submission. All of the 10/16% of bonus will be in the non-programming section.
#
# - We provided you .py files and all necessary libraries to complete the files have been added; these are the only allowed libraries that you can use for the homework. Don't remove existing imports or add new imports, as this will cause the autograder to discard your submission.
#
# - You are allowed to make as many submissions until the deadline as you like, and there are no hidden tests. This creates an incentive for students to use the autograder like a unittest runner. We think this is conducive to success on the homeworks, as it makes it clear what is expected of you, but it has the consequence of clogging up our runners for the last hour before the due date. You should expect Gradescope to slow down or even crash near the due date. Start early!

# %% [markdown]
# ### Using the local tests
#
# - For some of the programming questions we have included a local tests using a small toy datasets to aid in debugging. The local test sample data and outputs are stored in localtests.py.
# - It is possible to fail the local tests and pass the autograder. Likewise, it is possible to pass the local tests and fail the autograder.
# - **You do not need to pass local tests to get points, passing the Gradescope autograder is sufficient for full credit.**
# - Do not solely rely on the provided local tests. We recommend writing your own tests to further your understanding of the problem, and regularly testing against the autograder as you work. If you write a unittest suite, consider sharing it on Ed for other students to help them develop!

# %% [markdown]
# ## Deliverables and Points Distribution

# %% [markdown]
# ### Q1: Programming Warm-Up [5pts]
#
# #### Deliverables: <font color = 'green'>warmup.py</font>, <font color = 'green'>env.pkl</font>
#
# - **1.1 Setup** [2pts] - _programming_
#
# - **1.2 Numpy Warump** [3pts] - _programming_
#     - Basics [2pts]
#     - Broadcasting [1pts]

# %% [markdown]
# ## 1.1 Setup [2pts]

# %% [markdown]
# - **Deliverable:** `env.pkl`
#
# This homework and notebook is tested using the conda environment we provide. Please ensure that you have some distribution of anaconda installed (we provide a tutorial on [Ed](https://edstem.org/us/courses/90663/discussion/7539740)), then **please read `environment/environment_setup.md` and follow the instructions to set up an environment for this homework.**
#
# While this homework really only uses numpy, we included a bunch of packages that you may find indispensable in machine learning (and potentially on your project). Among these are:
#
# - [jupyter lab](https://jupyterlab.readthedocs.io/en/stable/): provides a web-based IDE with a built-in debugging functionality for jupyter notebooks
# - [numpy](https://numpy.org/doc/1.23/): a high performance math library backed by C, designed to speed up calculations
# - [matplotlib](https://matplotlib.org/users/pyplot_tutorial.html): allows you to make a variety of beautiful plots
# - [scikit learn](https://scikit-learn.org/stable/getting_started.html): provides many classical ML and data analysis algorithms
# - [pandas](https://pandas.pydata.org/docs/): provides many useful tools for organizing and manipulating data, especially heterogenously-typed tabular data
# - [seaborn](https://seaborn.pydata.org/tutorial/introduction.html): make plots with less fidgeting in matplotlib, especially for custom colormaps
#
# Once you've set up your environment, activate a Jupyter kernel using that environment (again, included in the [Ed tutorial](https://edstem.org/us/courses/90663/discussion/7539740)), and proceed running the subsequent cells.

# %%
###############################
### DO NOT CHANGE THIS CELL ###
###############################

import sys

sys.path.append("./utilities/")
sys.path.append("warmup.py")

import numpy as np

print("Version information")

print("python: {}".format(sys.version))
print("numpy: {}".format(np.__version__))


# %load_ext autoreload
# %autoreload 2
# ^^ These two magic commands set your imports to be auto-reloading.
# This means that when you save a change in another file,
# the import will automatically refresh without you needing to edit or restart the kernel.
# Out:
# Version information
# python: 3.14.3 | packaged by conda-forge | (main, Feb  5 2026, 06:02:07) [Clang 20.1.8 ]
# numpy: 2.4.2

# %% [markdown]
# ### Basics, Imports, and Directories

# %% [markdown]
# For the following part, you will need to ensure your notebook runtime is started in the correct directory. You can verify this with the following cell.

# %%
###############################
### DO NOT CHANGE THIS CELL ###
###############################

# RUN ME #
import os

os.getcwd()
# Out:
# '/Users/lagn1/Desktop/HW1'

# %% [markdown]
# This should be the path to the directory where this notebook is placed. You can actually run some limited shell commands using !

# %%
# !dir
# This should list all files located in our cwd.
# Out:
# zsh:1: command not found: dir

# %% [markdown]
# Because this is our current working directory, and you should be able to see `warmup.py`, we can import that as a module!

# %%
import warmup

dir(warmup)
# ^^ you should see some dunder functions that every module has, then the functions inside of warmup.py
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'argmax_1d',
#  'fast_manhattan',
#  'indices_of_k',
#  'mean_rows',
#  'np',
#  'sum_squares']

# %% [markdown]
# Note that we didn't do `print(dir(warmup))` or earlier `print(os.getcwd())`, and yet they still printed without the `print()` call. This is a curiosity of Jupyter notebooks. When run, Jupyter will try to pretty-print the last hanging resource in a cell.

# %%
x = 10  # definitions aren't hanging, so this won't print anything
y = 11  # definitions aren't hanging, so this won't print anything

x  # this is hanging, but it's not last, so it won't get printed
y  # this is the last hanging resource, so its contents should be printed
# Out:
# 11

# %% [markdown]
# ### Making the Deliverable

# %% [markdown]
# In the cell below, import the `PackageUtils` class from `utils.py` using the `from` keyword.

# %%
# YOUR CODE HERE #
from utils import PackageUtils

# %% [markdown]
# In the cell below, instantiate an instance of the `PackageUtils` class, then call the `get_packages` method upon that class instance to see what packages are installed in this notebook's runtime environment.

# %%
# YOUR CODE HERE #
pu = PackageUtils()
pu.get_packages()
# Out:
# anyio @ file:///home/conda/feedstock_root/build_artifacts/bld/rattler-build_anyio_1767719033/work
# appnope @ file:///home/conda/feedstock_root/build_artifacts/appnope_1733332318622/work
# argon2-cffi @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi_1749017159514/work
# argon2-cffi-bindings @ file:///Users/runner/miniforge3/conda-bld/argon2-cffi-bindings_1762509538435/work
# arrow @ file:///home/conda/feedstock_root/build_artifacts/bld/rattler-build_arrow_1760831179/work
# asttokens @ file:///home/conda/feedstock_root/build_artifacts/asttokens_1763409923949/work
# async-lru @ file:///home/conda/feedstock_root/build_artifacts/bld/rattler-build_async-lru_1768752884/work
# attrs @ file:///home/conda/feedstock_root/build_artifacts/bld/rattler-build_attrs_1764875182/work
# babel @ file:///home/conda/feedstock_root/build_artifacts/bld/rattler-build_babel_1770326844/work
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1764520477956/work
# ...

# %% [markdown]
# This should generate `env.pkl` but we're not done yet.

# %% [markdown]
# ### Local Testing & Debugging

# %% [markdown]
# Optional local tests using a small toy dataset are sometimes provided to aid in debugging. The local tests are all stored in localtests.py
# #### The autograder is the final arbiter
# - There are no points associated with passing or failing the local tests, you must still pass the autograder to get points.
# - It is possible to fail the local test and pass the autograder.
#     - The autograder may have tolerances to account for minor implementation differences.
#     - The reverse is also true, as the autograder may cover a larger number of corner cases.
# - **You do not need to pass both local and autograder tests to get points, passing the Gradescope autograder is sufficient for credit.**
#
# #### Work smarter, not harder
# - Read the stack trace carefully. Often it will tell you exactly what's wrong.
# - Understand what the local-test is doing. That way you can develop your own tests.
# - Grow beyond the print statement: embrace a debugger. Jupyter-lab has a [built in debugger](https://jupyterlab.readthedocs.io/en/stable/user/debugger.html) which allows you to look at data types, set breakpoints, and examine variables. If using a different IDE, look up your IDE's documentation on how to setup a proper debugger.
# - Develop incrementally and test frequently, both localy and on Gradescope. Waiting to complete the whole class before testing can make it hard to isolate errors.

# %% [markdown]
# For this problem perform the following in the cell below:
# - import `WarmupTests` from the `localtests.py`.
# - Run the provided code snippet and submit `env.pkl`

# %%
import unittest

# import WarmupTests from the localtests.py in the utilities folder.
from localtests import WarmupTests
# END YOUR CODE ABOVE #

# %%
###############################
### DO NOT CHANGE THIS CELL ###
###############################
result = unittest.main(
    argv=["ignored", "WarmupTests.test_get_packages"], verbosity=1, exit=False
)
if not result.result.wasSuccessful():
    sys.exit(1)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK
# Passed test_get_packages

# %% [markdown]
# For this homework, running that local test will edit your `env.pkl` with a fingerprint so that you will pass the autograder. In future scenarios, the localtests are completely optional, but we just want to make sure that you have the capability of running these on your system.

# %% [markdown]
# ## 1.2 Numpy Warmup [3pts]

# %% [markdown]
# ### 1.2.1 Basics [2pts]

# %% [markdown]
# The following exercise will familiarize you with the basics of working with Numpy and navigating the [numpy documentation](https://numpy.org/doc/1.23/reference/index.html)
#
# In `warmup.py` you will implement several "one-liners" using functions provided by numpy. No points will be awarded on Gradescope for any use of for loops or list comprehensions. Implement the following functions in `warmup.py`:
#
# - indices_of_k
# - argmax_1d
# - mean_rows
# - sum_squares
#
# You may test your implementation with the below local tests. These local tests only checks the returned values of your implementation and does not check whether your implementation uses loops. Gradescope will check to make sure your implementation does not use loops (for, while, or list comprehensions).
#
# <span style="color:red">**WARNING: Make sure you match the dimensions of the output given in the comments of required function in warmup.py**</span>
#
# <span style="color:red">HINT: Print and see what numpy functions are doing as much as you can!</span>

# %%
###############################
### DO NOT CHANGE THIS CELL ###
###############################
import unittest

result = unittest.main(argv=[""], verbosity=1, exit=False)

if not result.result.wasSuccessful():
    sys.exit(1)
# Out:
# .....
# ----------------------------------------------------------------------
# Ran 5 tests in 0.008s
#
# OK
# Correct Values for argmax_1d
# Passed test_get_packages
# Correct Values for indices_of_k
# Correct Values for mean_rows
# Correct Values for sum_squares

# %% [markdown]
# ### 1.2.2 Broadcasting [1pt]

# %% [markdown]
# One of the simplest and most common similarity metrics in ML is the Manhattan Distance or [taxicab-distance](https://en.wikipedia.org/wiki/Taxicab_geometry). The function below takes two lists of $N$ points in $D$ dimensional space (NxD numpy arrays) and computes the Manhattan distance between every possible pair of points. *Hint: you can use this to try creating your own unittests*

# %%
###############################
### DO NOT CHANGE THIS CELL ###
###############################

import numpy as np


def slow_manhattan(x, y):
    """
    Args:
        x: N x D numpy array
        y: M x D numpy array
     Return:
        dist: N x M numpy array, where dist[i, j] is the Manhattan distance between
        x[i, :] and y[j, :]
    """
    dist = np.empty((x.shape[0], y.shape[0]))
    for i in range(x.shape[0]):
        for j in range(y.shape[0]):
            d = 0
            for k in range(x.shape[1]):
                d += abs(x[i][k] - y[j][k])
            dist[i][j] = d
    return dist

# %% [markdown]
# Unfortunately such an implementation is too slow for a large dataset. In `fast_manhattan` leverage the [broadcasting](https://numpy.org/doc/2.3/user/basics.broadcasting.html) properties of numpy to create a faster version in a single line.

# %% [markdown]
# Let's test the speed of this naive, slow implementation:

# %%
# %%timeit

###############################
### DO NOT CHANGE THIS CELL ###
###############################


x = np.random.rand(100, 3)
y = np.random.rand(100, 3)
d = slow_manhattan(x, y)
# Out:
# 12.7 ms ± 1.27 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Compare this with the vectorized implementation:

# %%
###############################
### DO NOT CHANGE THIS CELL ###
###############################

import warmup

# %%
# %%timeit

###############################
### DO NOT CHANGE THIS CELL ###
###############################

x = np.random.rand(100, 3)
y = np.random.rand(100, 3)
d = warmup.fast_manhattan(x, y)
# Out:
# 169 μs ± 2.48 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# If you'd like, use this notebook to experiment with new data and reason carefully about the time and space complexities of these two algortihms.
